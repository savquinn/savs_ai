# %%
import sqlite3
import datetime
import json
from typing import List, Dict, Any, Optional

def get_chat_mapping(db_location):
    conn = sqlite3.connect(db_location)
    cursor = conn.cursor()
    cursor.execute("SELECT ROWID, room_name, display_name FROM chat")
    result_set = cursor.fetchall()
    # Include the ROWID (chat_id) in the mapping
    mapping = {row[0]: {"room_name": row[1], "display_name": row[2]} for row in result_set}
    conn.close()
    return mapping

def read_messages(db_location, n=10, self_number='Me', human_readable_date=True):
    conn = sqlite3.connect(db_location)
    cursor = conn.cursor()
    
    # Modified query to include chat_id from the chat_message_join table
    query = """
    SELECT 
        message.ROWID, 
        message.date, 
        message.text, 
        message.attributedBody, 
        handle.id, 
        message.is_from_me, 
        message.cache_roomnames,
        cmj.chat_id  -- Added chat_id from chat_message_join
    FROM message
    LEFT JOIN handle ON message.handle_id = handle.ROWID
    LEFT JOIN chat_message_join cmj ON message.ROWID = cmj.message_id
    """
    
    if n is not None:
        query += f" ORDER BY message.date DESC LIMIT {n}"
    
    results = cursor.execute(query).fetchall()
    messages = []
    
    chat_mapping = get_chat_mapping(db_location)
    
    for result in results:
        rowid, date, text, attributed_body, handle_id, is_from_me, cache_roomname, chat_id = result
        
        if handle_id is None:
            phone_number = self_number
        else:
            phone_number = handle_id
            
        if text is not None:
            body = text
        elif attributed_body is None:
            continue
        else:
            # Handle attributed body decoding
            attributed_body = attributed_body.decode('utf-8', errors='replace')
            if "NSNumber" in str(attributed_body):
                attributed_body = str(attributed_body).split("NSNumber")[0]
                if "NSString" in attributed_body:
                    attributed_body = str(attributed_body).split("NSString")[1]
                    if "NSDictionary" in attributed_body:
                        attributed_body = str(attributed_body).split("NSDictionary")[0]
                        attributed_body = attributed_body[6:-12]
                        body = attributed_body
        
        if human_readable_date:
            date_string = '2001-01-01'
            mod_date = datetime.datetime.strptime(date_string, '%Y-%m-%d')
            unix_timestamp = int(mod_date.timestamp())*1000000000
            new_date = int((date+unix_timestamp)/1000000000)
            date = datetime.datetime.fromtimestamp(new_date).strftime("%Y-%m-%d %H:%M:%S")
        
        # Get chat information if chat_id exists
        chat_info = None
        if chat_id is not None and chat_id in chat_mapping:
            chat_info = chat_mapping[chat_id]
            mapped_name = chat_info.get("display_name")
            room_name = chat_info.get("room_name")
        else:
            mapped_name = None
            room_name = cache_roomname
        
        messages.append({
            "rowid": rowid, 
            "date": date, 
            "body": body, 
            "phone_number": phone_number, 
            "is_from_me": is_from_me,
            "cache_roomname": cache_roomname, 
            'group_chat_name': mapped_name,
            'chat_id': chat_id  # Added chat_id to the output
        })
    
    conn.close()
    return messages

def print_messages(messages):
    for message in messages:
        print(f"RowID: {message['rowid']}")
        print(f"Chat ID: {message['chat_id']}")  # Added chat_id to the output
        print(f"Body: {message['body']}")
        print(f"Phone Number: {message['phone_number']}")
        print(f"Is From Me: {message['is_from_me']}")
        print(f"Cache Roomname: {message['cache_roomname']}")
        print(f"Group Chat Name: {message['group_chat_name']}")
        print(f"Date: {message['date']}")
        print("\n")

def group_messages_by_conversation(messages):
    """Group messages by conversation ID"""
    conversations = {}
    
    for message in messages:
        chat_id = message['chat_id']
        if chat_id is None:
            # Skip messages without a chat_id
            continue
            
        if chat_id not in conversations:
            conversations[chat_id] = {
                'chat_id': chat_id,
                'group_chat_name': message['group_chat_name'],
                'messages': []
            }
            
        conversations[chat_id]['messages'].append(message)
    
    # Sort conversations by the date of the most recent message
    for chat_id in conversations:
        conversations[chat_id]['messages'].sort(key=lambda x: x['date'])
        
    return conversations

# %%
import os
db_location = "~/Library/Messages/chat.db"
# Read most recent 1000 messages
db_location = os.path.expanduser(db_location)
messages = read_messages(db_location, n=25000)

# Group them by conversation
conversations = group_messages_by_conversation(messages)

# Print conversation statistics
print(f"Found {len(conversations)} conversations")
# Out:
# Found 102 conversations

# %%
# Print a summary of each conversation
for chat_id, convo in conversations.items():
    print(f"Conversation: {convo['group_chat_name'] or 'Unknown'} (ID: {chat_id})")
    print(f"  Message count: {len(convo['messages'])}")
    if convo['messages']:
        first_msg = convo['messages'][0]['date']
        last_msg = convo['messages'][-1]['date']
        print(f"  Date range: {first_msg} to {last_msg}")
    print()
# Out:
# Conversation: Unknown (ID: 466)
#   Message count: 54
#   Date range: 2025-04-22 23:25:36 to 2025-05-07 01:29:31
#
# Conversation: Unknown (ID: 58)
#   Message count: 57
#   Date range: 2025-04-08 03:33:44 to 2025-05-07 01:25:24
#
# Conversation: Unknown (ID: 315)
#   Message count: 434
#   Date range: 2025-04-17 19:32:54 to 2025-05-06 22:58:14
#
# Conversation: Aquatic Avian Kids (ID: 37)
#   Message count: 334
#   Date range: 2025-04-08 05:43:43 to 2025-05-06 22:38:37
#
# Conversation: Unknown (ID: 7)
#   Message count: 102
#   Date range: 2025-04-09 00:15:37 to 2025-05-06 21:01:54
#
# Conversation: Book Report Club - TEAM BOOKWORMS (ID: 339)
#   Message count: 30
#   Date range: 2025-04-07 06:18:57 to 2025-05-06 19:06:23
#
# Conversation: Groussangerpeltz Chat (ID: 357)
#   Message count: 135
#   Date range: 2025-04-06 20:20:51 to 2025-05-06 18:33:22
#
# Conversation: Unknown (ID: 104)
#   Message count: 7
#   Date range: 2025-05-06 17:29:47 to 2025-05-06 17:38:44
#
# Conversation: Unknown (ID: 16)
#   Message count: 123
#   Date range: 2025-04-06 19:33:32 to 2025-05-06 16:58:59
#
# Conversation: Unknown (ID: 88)
#   Message count: 10
#   Date range: 2025-05-06 05:10:25 to 2025-05-06 14:45:08
#
# Conversation: Unknown (ID: 456)
#   Message count: 962
#   Date range: 2025-04-10 02:53:34 to 2025-05-06 07:09:36
#
# Conversation: Unknown (ID: 17)
#   Message count: 128
#   Date range: 2025-04-08 03:04:01 to 2025-05-06 04:45:45
#
# Conversation: Miss Idioms School for Troubled Girls (ID: 2)
#   Message count: 254
#   Date range: 2025-04-08 05:42:26 to 2025-05-06 03:06:29
#
# Conversation: Ohana (ID: 51)
#   Message count: 27
#   Date range: 2025-04-29 22:15:22 to 2025-05-06 03:00:45
#
# Conversation: Fire (ID: 370)
#   Message count: 82
#   Date range: 2025-04-10 21:36:43 to 2025-05-06 02:06:57
#
# Conversation: Unknown (ID: 145)
#   Message count: 90
#   Date range: 2025-04-08 18:29:29 to 2025-05-06 02:05:00
#
# Conversation: Unknown (ID: 12)
#   Message count: 167
#   Date range: 2025-04-17 11:22:46 to 2025-05-06 00:32:28
#
# Conversation: Extended Frisks (ID: 30)
#   Message count: 474
#   Date range: 2025-04-07 17:41:01 to 2025-05-05 21:58:10
#
# Conversation: Unknown (ID: 219)
#   Message count: 9
#   Date range: 2025-04-16 00:50:57 to 2025-05-05 20:58:49
#
# Conversation: Unknown (ID: 83)
#   Message count: 98
#   Date range: 2025-04-15 00:48:17 to 2025-05-05 19:56:17
#
# Conversation: Unknown (ID: 477)
#   Message count: 34
#   Date range: 2025-05-04 21:08:38 to 2025-05-05 19:27:24
#
# Conversation: Unknown (ID: 476)
#   Message count: 16
#   Date range: 2025-05-03 22:18:03 to 2025-05-05 18:41:00
#
# Conversation: Unknown (ID: 140)
#   Message count: 8
#   Date range: 2025-04-19 20:50:03 to 2025-05-05 05:22:02
#
# Conversation: Unknown (ID: 13)
#   Message count: 73
#   Date range: 2025-04-08 04:44:42 to 2025-05-05 03:13:35
#
# Conversation: Unknown (ID: 478)
#   Message count: 13
#   Date range: 2025-05-05 01:22:12 to 2025-05-05 03:03:35
#
# Conversation: Unknown (ID: 283)
#   Message count: 80
#   Date range: 2025-04-09 23:39:17 to 2025-05-05 00:20:46
#
# Conversation: Unknown (ID: 467)
#   Message count: 50
#   Date range: 2025-04-24 18:36:01 to 2025-05-04 21:49:27
#
# Conversation: Ulticello Grown Up (ID: 60)
#   Message count: 67
#   Date range: 2025-04-14 23:46:27 to 2025-05-03 12:17:29
#
# Conversation: Unknown (ID: 33)
#   Message count: 4
#   Date range: 2025-04-12 08:45:14 to 2025-05-03 03:53:40
#
# Conversation: Unknown (ID: 341)
#   Message count: 6
#   Date range: 2025-04-28 00:02:44 to 2025-05-02 03:32:42
#
# Conversation: Unknown (ID: 76)
#   Message count: 89
#   Date range: 2025-04-11 02:11:14 to 2025-05-02 00:24:19
#
# Conversation: Unknown (ID: 330)
#   Message count: 51
#   Date range: 2025-04-09 21:22:12 to 2025-05-02 00:22:20
#
# Conversation: Unknown (ID: 64)
#   Message count: 4
#   Date range: 2025-05-01 22:17:51 to 2025-05-02 00:11:50
#
# Conversation: Unknown (ID: 469)
#   Message count: 23
#   Date range: 2025-04-26 20:03:46 to 2025-05-02 00:08:50
#
# Conversation: Unknown (ID: 472)
#   Message count: 16
#   Date range: 2025-04-29 18:43:21 to 2025-05-01 22:12:03
#
# Conversation: Unknown (ID: 80)
#   Message count: 15
#   Date range: 2025-05-01 18:06:04 to 2025-05-01 18:12:15
#
# Conversation: Unknown (ID: 328)
#   Message count: 6
#   Date range: 2025-05-01 17:50:05 to 2025-05-01 18:10:12
#
# Conversation: Unknown (ID: 475)
#   Message count: 10
#   Date range: 2025-05-01 16:05:23 to 2025-05-01 16:50:53
#
# Conversation: Unknown (ID: 1)
#   Message count: 139
#   Date range: 2025-04-06 20:15:35 to 2025-05-01 16:12:24
#
# Conversation: Unknown (ID: 139)
#   Message count: 128
#   Date range: 2025-04-06 20:09:03 to 2025-05-01 03:54:36
#
# Conversation: Unknown (ID: 474)
#   Message count: 4
#   Date range: 2025-05-01 00:13:44 to 2025-05-01 00:26:38
#
# Conversation: Unknown (ID: 144)
#   Message count: 24
#   Date range: 2025-04-09 01:44:20 to 2025-04-30 21:10:09
#
# Conversation: Unknown (ID: 432)
#   Message count: 5
#   Date range: 2025-04-22 16:19:19 to 2025-04-30 21:01:19
#
# Conversation: Unknown (ID: 233)
#   Message count: 2
#   Date range: 2025-04-30 06:52:16 to 2025-04-30 07:54:55
#
# Conversation: Unknown (ID: 21)
#   Message count: 71
#   Date range: 2025-04-29 02:39:46 to 2025-04-30 01:47:52
#
# Conversation: Unknown (ID: 28)
#   Message count: 16
#   Date range: 2025-04-29 21:44:27 to 2025-04-29 23:51:30
#
# Conversation: Unknown (ID: 473)
#   Message count: 4
#   Date range: 2025-04-29 20:03:35 to 2025-04-29 23:35:12
#
# Conversation: Unknown (ID: 398)
#   Message count: 1
#   Date range: 2025-04-29 20:34:42 to 2025-04-29 20:34:42
#
# Conversation: Unknown (ID: 15)
#   Message count: 6
#   Date range: 2025-04-29 05:20:55 to 2025-04-29 09:24:04
#
# Conversation: Montichella (ID: 170)
#   Message count: 297
#   Date range: 2025-04-08 04:55:47 to 2025-04-28 22:10:18
#
# Conversation: MarshFam (ID: 279)
#   Message count: 7
#   Date range: 2025-04-28 20:29:31 to 2025-04-28 21:59:14
#
# Conversation: Unknown (ID: 465)
#   Message count: 80
#   Date range: 2025-04-22 16:18:19 to 2025-04-28 16:58:40
#
# Conversation: Unknown (ID: 471)
#   Message count: 4
#   Date range: 2025-04-28 07:03:03 to 2025-04-28 07:05:33
#
# Conversation: Unknown (ID: 27)
#   Message count: 71
#   Date range: 2025-04-08 21:41:58 to 2025-04-28 07:02:44
#
# Conversation: AI/ML Consortium (ID: 286)
#   Message count: 15
#   Date range: 2025-04-18 19:03:44 to 2025-04-28 03:50:29
#
# Conversation: Unknown (ID: 91)
#   Message count: 1
#   Date range: 2025-04-28 03:34:04 to 2025-04-28 03:34:04
#
# Conversation: Unknown (ID: 5)
#   Message count: 12
#   Date range: 2025-04-28 01:22:30 to 2025-04-28 02:18:43
#
# Conversation: Unknown (ID: 470)
#   Message count: 5
#   Date range: 2025-04-27 22:30:38 to 2025-04-27 22:55:55
#
# Conversation: Unknown (ID: 25)
#   Message count: 31
#   Date range: 2025-04-07 18:06:12 to 2025-04-26 19:56:01
#
# Conversation: Unknown (ID: 22)
#   Message count: 50
#   Date range: 2025-04-06 20:47:51 to 2025-04-25 18:06:57
#
# Conversation: Unknown (ID: 468)
#   Message count: 12
#   Date range: 2025-04-24 22:42:02 to 2025-04-25 00:04:11
#
# Conversation: Unknown (ID: 123)
#   Message count: 29
#   Date range: 2025-04-24 03:31:44 to 2025-04-24 05:11:59
#
# Conversation: Unknown (ID: 74)
#   Message count: 27
#   Date range: 2025-04-07 04:19:21 to 2025-04-24 04:47:38
#
# Conversation: Unknown (ID: 452)
#   Message count: 11
#   Date range: 2025-04-17 18:00:28 to 2025-04-24 00:07:46
#
# Conversation: Unknown (ID: 136)
#   Message count: 4
#   Date range: 2025-04-23 02:28:45 to 2025-04-23 02:51:41
#
# Conversation: Unknown (ID: 245)
#   Message count: 17
#   Date range: 2025-04-18 00:55:43 to 2025-04-21 23:22:37
#
# Conversation: Unknown (ID: 35)
#   Message count: 4
#   Date range: 2025-04-21 21:24:22 to 2025-04-21 21:36:28
#
# Conversation: Unknown (ID: 38)
#   Message count: 17
#   Date range: 2025-04-16 05:39:19 to 2025-04-20 22:58:10
#
# Conversation: Unknown (ID: 260)
#   Message count: 34
#   Date range: 2025-04-10 07:14:26 to 2025-04-19 20:33:36
#
# Conversation: Unknown (ID: 45)
#   Message count: 66
#   Date range: 2025-04-08 01:07:05 to 2025-04-19 06:31:53
#
# Conversation: Marathon Mamis (ID: 101)
#   Message count: 4
#   Date range: 2025-04-18 19:37:35 to 2025-04-19 01:23:57
#
# Conversation: Bamboo crew (ID: 29)
#   Message count: 11
#   Date range: 2025-04-16 17:03:05 to 2025-04-18 20:22:49
#
# Conversation: Fellowship of the Bach  (ID: 461)
#   Message count: 54
#   Date range: 2025-04-13 23:26:41 to 2025-04-17 18:48:38
#
# Conversation: Unknown (ID: 463)
#   Message count: 39
#   Date range: 2025-04-15 06:39:47 to 2025-04-17 02:41:57
#
# Conversation: Unknown (ID: 464)
#   Message count: 13
#   Date range: 2025-04-16 18:30:48 to 2025-04-16 22:04:12
#
# Conversation: Unknown (ID: 155)
#   Message count: 6
#   Date range: 2025-04-15 18:30:51 to 2025-04-15 20:47:22
#
# Conversation: Unknown (ID: 412)
#   Message count: 37
#   Date range: 2025-04-11 20:38:19 to 2025-04-15 01:18:18
#
# Conversation: Unknown (ID: 459)
#   Message count: 15
#   Date range: 2025-04-11 18:13:55 to 2025-04-14 22:33:35
#
# Conversation: Unknown (ID: 462)
#   Message count: 7
#   Date range: 2025-04-14 21:52:14 to 2025-04-14 22:07:28
#
# Conversation: Chella homies (ID: 90)
#   Message count: 8
#   Date range: 2025-04-07 21:52:58 to 2025-04-14 04:28:34
#
# Conversation: Unknown (ID: 402)
#   Message count: 60
#   Date range: 2025-04-11 23:07:54 to 2025-04-14 03:48:09
#
# Conversation: Unknown (ID: 253)
#   Message count: 2
#   Date range: 2025-04-13 20:02:42 to 2025-04-13 20:24:22
#
# Conversation: Unknown (ID: 460)
#   Message count: 2
#   Date range: 2025-04-13 05:51:22 to 2025-04-13 05:52:22
#
# Conversation: Unknown (ID: 301)
#   Message count: 42
#   Date range: 2025-04-08 19:39:25 to 2025-04-13 04:38:02
#
# Conversation: Unknown (ID: 111)
#   Message count: 6
#   Date range: 2025-04-08 00:44:51 to 2025-04-13 03:24:35
#
# Conversation: LA Book Club (ID: 124)
#   Message count: 10
#   Date range: 2025-04-11 06:32:39 to 2025-04-13 02:16:24
#
# Conversation: Unknown (ID: 163)
#   Message count: 18
#   Date range: 2025-04-10 19:48:15 to 2025-04-12 03:33:12
#
# Conversation: Unknown (ID: 455)
#   Message count: 13
#   Date range: 2025-04-09 00:35:53 to 2025-04-11 20:34:50
#
# Conversation: Unknown (ID: 393)
#   Message count: 24
#   Date range: 2025-04-10 19:13:44 to 2025-04-11 00:28:46
#
# Conversation: Unknown (ID: 458)
#   Message count: 11
#   Date range: 2025-04-10 21:24:03 to 2025-04-10 21:39:28
#
# Conversation: Unknown (ID: 457)
#   Message count: 4
#   Date range: 2025-04-10 20:35:41 to 2025-04-10 20:42:15
#
# Conversation: Unknown (ID: 277)
#   Message count: 8
#   Date range: 2025-04-07 15:58:18 to 2025-04-10 19:41:13
#
# Conversation: Unknown (ID: 311)
#   Message count: 10
#   Date range: 2025-04-09 18:42:14 to 2025-04-10 01:57:31
#
# Conversation: Unknown (ID: 120)
#   Message count: 4
#   Date range: 2025-04-09 21:59:29 to 2025-04-09 23:39:23
#
# Conversation: Unknown (ID: 237)
#   Message count: 4
#   Date range: 2025-04-09 18:36:19 to 2025-04-09 23:26:56
#
# Conversation: Unknown (ID: 454)
#   Message count: 9
#   Date range: 2025-04-07 17:25:27 to 2025-04-09 18:49:36
#
# Conversation: Unknown (ID: 11)
#   Message count: 4
#   Date range: 2025-04-08 22:43:57 to 2025-04-09 04:03:51
#
# Conversation: Unknown (ID: 395)
#   Message count: 31
#   Date range: 2025-04-07 21:56:26 to 2025-04-08 07:23:15
#
# Conversation: NY state of mind (ID: 44)
#   Message count: 5
#   Date range: 2025-04-08 02:11:52 to 2025-04-08 03:04:18
#
# Conversation: Unknown (ID: 73)
#   Message count: 3
#   Date range: 2025-04-08 01:02:37 to 2025-04-08 01:08:28
#
# Conversation: Unknown (ID: 110)
#   Message count: 3
#   Date range: 2025-04-08 00:31:12 to 2025-04-08 00:46:44
#
# Conversation: Trapdoor Shitposting™ (ID: 344)
#   Message count: 5
#   Date range: 2025-04-07 04:11:42 to 2025-04-07 11:52:50
