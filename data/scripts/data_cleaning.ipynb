# %%
    # Import the reset function
from reset_pipeline import reset_pipeline_databases

# When you want to start over:
reset_pipeline_databases()

# Then run your pipeline
from extract_raw import main as extract_raw
from clean_data import main as clean_data

# Run the pipeline
extract_raw()
clean_data()

# Now you can inspect the results
import sqlite3
import pandas as pd

# Look at raw messages
raw_conn = sqlite3.connect("data/raw/raw_messages.db")
raw_messages = pd.read_sql_query("SELECT * FROM messages", raw_conn)
print("Raw messages:", len(raw_messages))
raw_conn.close()

# Look at cleaned messages
cleaned_conn = sqlite3.connect("data/processed/cleaned_messages.db")
cleaned_messages = pd.read_sql_query("SELECT * FROM cleaned_messages", cleaned_conn)
print("Cleaned messages:", len(cleaned_messages))
cleaned_conn.close()
# Out:
# 2025-05-07 18:53:37,161 - INFO - No raw database found
# 2025-05-07 18:53:37,162 - INFO - No cleaned database found
# 2025-05-07 18:53:37,163 - INFO - Pipeline databases have been reset. You can now run the pipeline from scratch.
# 2025-05-07 18:53:37,166 - INFO - Set up raw database at data/raw/raw_messages.db
# 2025-05-07 18:53:37,167 - INFO - Creating temporary copy of /Users/sfrisk/Library/Messages/chat.db
# 2025-05-07 18:53:37,180 - INFO - Last processed message ID: 0
# 2025-05-07 18:53:37,184 - INFO - Fetching new messages...
# 2025-05-07 18:53:37,387 - INFO - Processed 3350 new messages
# 2025-05-07 18:53:37,391 - INFO - Successfully processed 3350 messages
# 2025-05-07 18:53:37,392 - INFO - Set up cleaned database at data/processed/cleaned_messages.db
# 2025-05-07 18:53:37,392 - INFO - Last cleaned message ID: 0
# 2025-05-07 18:53:37,393 - INFO - Fetching new messages to clean...
# 2025-05-07 18:53:37,519 - INFO - Cleaned 3182 messages
# ...

# %%
raw_messages
# Out:
#       message_id  chat_id                                               text  \
# 0          66064      139  ped���@���NSMutableAttributedString��NSAt...
# 1          66075       16  ped���@���NSMutableAttributedString��NSAt...
# 2          66079      139  ped���@���NSMutableAttributedString��NSAt...
# 3          66098       22  ped���@���NSMutableAttributedString��NSAt...
# 4          66118        1  ped���@���NSMutableAttributedString��NSAt...
# ...          ...      ...                                                ...
# 3345       75523      300                 I'm so sorry for withholding them
# 3346       75524      300                    I'm transferring them tomorrow!
# 3347       75526      300  No im sorry for leaving them with you! thank y...
# 3348       75533       17                                               ￼Now
# 3349       75534       17                                               lol
#
#                 timestamp  is_from_me    contact_id  has_media  \
# ...
